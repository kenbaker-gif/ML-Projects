# %% [markdown]
# ## Model_2
# <p>We skipped the data exploratory part and analysis since we already had done it in model-1 and now we need to test using Polynomial features</p>

# %%
# Loading the dataset
import pandas as pd
data = pd.read_csv("/home/kenbaker-gif/ML-Projects/Boston/data/train.csv")
data_2 = pd.read_csv("/home/kenbaker-gif/ML-Projects/Boston/data/test.csv")

# %%
# using polynomial features
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
X = data[["rm", "lstat"]]
y = data["medv"]

poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)

scaler2 = StandardScaler()
X_train_scaled = scaler2.fit_transform(X_train)
X_test_scaled = scaler2.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model_2 = LinearRegression()
model_2.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_squared_error
y_pred = model_2.predict(X_test_scaled)
print(f"MSE:---> {mean_squared_error(y_test, y_pred)}")
print(f"r2Score:---> {r2_score(y_test, y_pred)}")
# Out:
# MSE:---> 13.845778748739106
# r2Score:---> 0.8461552493354628

# %%
# Visualizing the data
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Linear Regression: Actual vs Predicted')
plt.show()
